# %%
import pandas as pd
import numpy as np
from textblob import TextBlob
# !pip install textblob
# Out:
# ...
# WARNING: You are using pip version 21.3.1; however, version 22.3.1 is available.
# You should consider upgrading via the '/home/dhruv/anaconda3/bin/python -m pip install --upgrade pip' command.

# %%
df=pd.read_csv('sales.csv')
df.head()
# Out:
#                               Region                Country        Item_Type  \
# 0              Australia and Oceania                 Tuvalu        Baby Food
# 1  Central America and the Caribbean                Grenada           Cereal
# 2                             Europe                 Russia  Office Supplies
# 3                 Sub_Saharan Africa  Sao Tome and Principe           Fruits
# 4                 Sub_Saharan Africa                 Rwanda  Office Supplies
#
#   Sales_Channel Order_Priority Ship_Date  Unit_Cost  Total_Revenue  \
# 0       Offline              H  27-06-10     159.42     2533654.00
# 1        Online              C  15-09-12     117.11      576782.80
# 2       Offline              L  05-08-14     524.96     1158502.59
# 3        Online              C  07-05-14       6.92       75591.66
# 4       Offline              L  02-06-13     524.96     3296425.02
#
#    Total_Profit  Unnamed: 9  Unnamed: 10
# 0     951410.50         NaN          NaN
# ...

# %%
df.columns
# Out:
# Index(['Region', 'Country', 'Item_Type', 'Sales_Channel', 'Order_Priority',
#        'Ship_Date', 'Unit_Cost', 'Total_Revenue', 'Total_Profit', 'Unnamed: 9',
#        'Unnamed: 10'],
#       dtype='object')

# %%
df[df.columns[0:2]]
# Out:
#                                Region                Country
# 0               Australia and Oceania                 Tuvalu
# 1   Central America and the Caribbean                Grenada
# 2                              Europe                 Russia
# 3                  Sub_Saharan Africa  Sao Tome and Principe
# 4                  Sub_Saharan Africa                 Rwanda
# ..                                ...                    ...
# 95                 Sub_Saharan Africa                   Mali
# 96                               Asia               Malaysia
# 97                 Sub_Saharan Africa           Sierra Leone
# 98                      North America                 Mexico
# 99                 Sub_Saharan Africa             Mozambique
#
# [100 rows x 2 columns]

# %%
#loc and iloc to control rows and cols
df.loc[0,'Country']
# Out:
# 'Tuvalu'

# %%
df.iloc[0,1]
# Out:
# 'Tuvalu'

# %%
#multi rows
df.loc[[12,34,56],['Country','Region']]
# Out:
#        Country                 Region
# 12  Bangladesh                   Asia
# 34    Djibouti     Sub_Saharan Africa
# 56        Fiji  Australia and Oceania

# %%
len(df[df.Sales_Channel!='Offline'])
# Out:
# 50

# %%
df[(df.Total_Revenue>70000) & (df.Total_Profit>100000)]
# Out:
#                                Region          Country        Item_Type  \
# 0               Australia and Oceania           Tuvalu        Baby Food
# 1   Central America and the Caribbean          Grenada           Cereal
# 2                              Europe           Russia  Office Supplies
# 4                  Sub_Saharan Africa           Rwanda  Office Supplies
# 5               Australia and Oceania  Solomon Islands        Baby Food
# ..                                ...              ...              ...
# 92       Middle East and North Africa       Azerbaijan  Office Supplies
# 93                             Europe          Romania        Cosmetics
# 94  Central America and the Caribbean        Nicaragua        Beverages
# 98                      North America           Mexico    Personal Care
# 99                 Sub_Saharan Africa       Mozambique        Household
#
#    Sales_Channel Order_Priority Ship_Date  Unit_Cost  Total_Revenue  \
# ...

# %%
df=pd.read_csv('cloths-rating.csv')
df.head()
# Out:
#    ProductID                UserID  Rating  \
# 0        777  AV1YnR7wglJLPUi8IJmi       4
# 1        767  AVpfpK8KLJeJML43BCuD       4
# 2       1080  AVqkIdntQMlgsOJE6fuB       5
# 3       1077  AVpfpK8KLJeJML43BCuD       3
# 4       1049  AVpfpK8KLJeJML43BCuD       5
#
#                                                 Text
# 0                      Great taffy at a great price.
# 1  Absolutely wonderful - silky and sexy and comf...
# 2                 Love this dress! it's sooo pretty.
# 3  I had such high hopes for this dress and reall...
# 4  I love, love, love this jumpsuit. it's fun, fl...

# %%
def sentiment(text):
    try:
        return TextBlob(str(text)).sentiment.polarity
    except:
        return None
df['sentiment']=df['Text'].apply(sentiment)
df
# Out:
#      ProductID                UserID  Rating  \
# 0          777  AV1YnR7wglJLPUi8IJmi       4
# 1          767  AVpfpK8KLJeJML43BCuD       4
# 2         1080  AVqkIdntQMlgsOJE6fuB       5
# 3         1077  AVpfpK8KLJeJML43BCuD       3
# 4         1049  AVpfpK8KLJeJML43BCuD       5
# ..         ...                   ...     ...
# 629        823            B08GWV3SM6       1
# 630        823            B08GWV3SM6       3
# 631        847            B08GWV3SM6       5
# 632        910  AVph0EeEilAPnD_x9myq       3
# 633        333  AVqkIdntQMlgsOJE6fuB       5
#
#                                                   Text  sentiment
# 0                        Great taffy at a great price.   0.800000
# 1    Absolutely wonderful - silky and sexy and comf...   0.633333
# 2                   Love this dress! it's sooo pretty.   0.437500
# 3    I had such high hopes for this dress and reall...   0.120000
# 4    I love, love, love this jumpsuit. it's fun, fl...   0.550000
# ...

# %%
df['updated_score']=df['Rating']*df['sentiment']
df
# Out:
#      ProductID                UserID  Rating  \
# 0          777  AV1YnR7wglJLPUi8IJmi       4
# 1          767  AVpfpK8KLJeJML43BCuD       4
# 2         1080  AVqkIdntQMlgsOJE6fuB       5
# 3         1077  AVpfpK8KLJeJML43BCuD       3
# 4         1049  AVpfpK8KLJeJML43BCuD       5
# ..         ...                   ...     ...
# 629        823            B08GWV3SM6       1
# 630        823            B08GWV3SM6       3
# 631        847            B08GWV3SM6       5
# 632        910  AVph0EeEilAPnD_x9myq       3
# 633        333  AVqkIdntQMlgsOJE6fuB       5
#
#                                                   Text  sentiment  \
# 0                        Great taffy at a great price.   0.800000
# 1    Absolutely wonderful - silky and sexy and comf...   0.633333
# 2                   Love this dress! it's sooo pretty.   0.437500
# 3    I had such high hopes for this dress and reall...   0.120000
# 4    I love, love, love this jumpsuit. it's fun, fl...   0.550000
# ...

# %%
def classify_scores(a):
    if a<= -0.25:
        z=1
    elif a<=1:
        z=2
    elif a<=2:
        z=3
    elif a<=3:
        z=4
    elif a<=4:
        z=5
    return v
df['new_score']= df['updated_score'].apply(classify_scores)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-15-c1e0b305408b> in <module>
#      11         z=5
#      12     return v
# ---> 13 df['new_score']= df['updated_score'].apply(classify_scores)
#
# ~/anaconda3/lib/python3.8/site-packages/pandas/core/series.py in apply(self, func, convert_dtype, args, **kwargs)
#    4355         dtype: float64
#    4356         """
# -> 4357         return SeriesApply(self, func, convert_dtype, args, kwargs).apply()
#    4358
#    4359     def _reduce(
#
# ~/anaconda3/lib/python3.8/site-packages/pandas/core/apply.py in apply(self)
#    1041             return self.apply_str()
#    1042
# -> 1043         return self.apply_standard()
#    1044
#    1045     def agg(self):
#
# ~/anaconda3/lib/python3.8/site-packages/pandas/core/apply.py in apply_standard(self)
# ...

# %%
import os
import nltk
print(os.listdir(nltk.data.find('corpora')))
nltk.download(gutenberg)
# Out:
# ['stopwords', 'stopwords.zip']
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-17-fa62225dfe71> in <module>
#       2 import nltk
#       3 print(os.listdir(nltk.data.find('corpora')))
# ----> 4 nltk.download(gutenberg)
#
# NameError: name 'gutenberg' is not defined
